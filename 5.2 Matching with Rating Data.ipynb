# %% [markdown]
# # We match our rating data to the main dataset

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from datetime import date

# %% [markdown]
# ## Loading data

# %%
ratings_df = pd.read_csv('Prepared Frames/rating_data.csv')
df_companies = pd.read_csv('Prepared Frames/companies_approx_match.csv')
main_df = pd.read_csv('Prepared Frames/main_data.csv')

# %% [markdown]
# ## Merging the found matches to the main Dataframe

# %%
main_df = pd.merge(left = main_df,
                                 right = df_companies[['Ticker','difflib']],
                                 # We use outer to not loose Information, we will have to get rid of some NaNs later
                                 how = 'left', 
                                 left_on = ['Ticker'], 
                                 right_on= ['Ticker'])

# %% [markdown]
# ## Assigning the ratings
# We now have to assign the ratings. The difficulty is, that we don't have the exact dates to match, but have to match when the date in the main dataframe is greater than the one for the rating and have to overwrite it with a new rating in case there is one.

# %%
# We can only assign ratings where we have found the companies, 
# we create a new dataframe just with these entries
df_rated = main_df[main_df['difflib'].isna()==False].copy()

# %%
# We sort the dataframe by dates
df_rated = df_rated.sort_values(by = ['Report Date'], ascending = True)
df_rated.head(3)
# Out:
#       Ticker                 Company Name  IndustryId  Fiscal Year  \
# 18103   KEYS  Keysight Technologies, Inc.    101001.0         2017
# 17887    JWN                NORDSTROM INC    103002.0         2016
# 5334    BURL      Burlington Stores, Inc.    102001.0         2016
#
#       Fiscal Period Report Date  Shares (Diluted)  \
# 18103            Q1  2017-01-31       173000000.0
# 17887            Q4  2017-01-31       178500000.0
# 5334             Q4  2017-01-31        70877000.0
#
#        Cash, Cash Equivalents & Short Term Investments  \
# 18103                                     8.960000e+08
# 17887                                     1.007000e+09
# 5334                                      8.159700e+07
#
#        Accounts & Notes Receivable  Total Current Assets  ...  \
# 18103                  395000000.0          1.932000e+09  ...
# 17887                  199000000.0          3.242000e+09  ...
# 5334                    43252000.0          9.283240e+08  ...
#
#        Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 18103                      0.0           152000000.0
# 17887                      0.0           393000000.0
# 5334                       0.0           190532000.0
#
#        Income Tax (Expense) Benefit, Net  \
# 18103                        -43000000.0
# 17887                       -192000000.0
# 5334                         -64971000.0
#
#        Income (Loss) from Continuing Operations  \
# 18103                               109000000.0
# 17887                               201000000.0
# 5334                                125561000.0
#
#        Net Extraordinary Gains (Losses)   Net Income  Net Income (Common)  \
# 18103                               0.0  109000000.0          109000000.0
# 17887                               0.0  201000000.0          201000000.0
# 5334                                0.0  125561000.0          125561000.0
#
#                    Sector                      Industry  \
# 18103          Technology             Computer Hardware
# 17887   Consumer Cyclical  Retail - Apparel & Specialty
# 5334   Consumer Defensive            Retail - Defensive
#
#                            difflib
# 18103  keysight technologies, inc.
# 17887              nordstrom, inc.
# 5334       burlington stores, inc.
#
# [3 rows x 40 columns]

# %%
# Since we matched the names of the companies on the lowercase version, we have to create a column  with that version again
ratings_df['Company_lower'] = ratings_df['Company'].apply(lambda x: x.lower())

# %%
# We create a list of all unique companies in our ratings dataframe
companies = list(df_rated['difflib'].unique())

# %% [markdown]
# #### Checking if we can match right

# %%
df_rated[df_rated['difflib']==companies[0]].head(2)
# Out:
#       Ticker                 Company Name  IndustryId  Fiscal Year  \
# 18103   KEYS  Keysight Technologies, Inc.    101001.0         2017
# 18104   KEYS  Keysight Technologies, Inc.    101001.0         2017
#
#       Fiscal Period Report Date  Shares (Diluted)  \
# 18103            Q1  2017-01-31       173000000.0
# 18104            Q2  2017-04-30       179000000.0
#
#        Cash, Cash Equivalents & Short Term Investments  \
# 18103                                     8.960000e+08
# 18104                                     1.023000e+09
#
#        Accounts & Notes Receivable  Total Current Assets  ...  \
# 18103                  395000000.0          1.932000e+09  ...
# 18104                  518000000.0          2.314000e+09  ...
#
#        Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 18103                      0.0           152000000.0
# 18104                      0.0            22000000.0
#
#        Income Tax (Expense) Benefit, Net  \
# 18103                        -43000000.0
# 18104                         27000000.0
#
#        Income (Loss) from Continuing Operations  \
# 18103                               109000000.0
# 18104                                49000000.0
#
#        Net Extraordinary Gains (Losses)   Net Income  Net Income (Common)  \
# 18103                               0.0  109000000.0          109000000.0
# 18104                               0.0   49000000.0           49000000.0
#
#            Sector           Industry                      difflib
# 18103  Technology  Computer Hardware  keysight technologies, inc.
# 18104  Technology  Computer Hardware  keysight technologies, inc.
#
# [2 rows x 40 columns]

# %%
ratings_df[ratings_df['Company_lower']==companies[0]]
# Out:
#                            Company        Date Rating  \
# 49310  Keysight Technologies, Inc.  2014-09-12   Baa3
# 49311  Keysight Technologies, Inc.  2019-08-14   Baa2
#
#                      Company_lower
# 49310  keysight technologies, inc.
# 49311  keysight technologies, inc.

# %%
ratings_df.columns
# Out:
# Index(['Company', 'Date', 'Rating', 'Company_lower'], dtype='object')

# %% [markdown]
# #### We have to make sure to overwrite only the greater dates with updated rating information
# We will test it manually for the first company and do the rest with a function

# %%
# First create a sub-dataframe only with the ratings we are interested in
current_ratings = ratings_df[ratings_df['Company_lower']==companies[0]].sort_values(by = ['Date'], ascending = True).reset_index(drop = True)
current_ratings
# Out:
#                        Company        Date Rating                Company_lower
# 0  Keysight Technologies, Inc.  2014-09-12   Baa3  keysight technologies, inc.
# 1  Keysight Technologies, Inc.  2019-08-14   Baa2  keysight technologies, inc.

# %%
for action in range(len(current_ratings)):
    # Getting the needed information
    company = current_ratings.loc[action,'Company_lower']
    date = current_ratings.loc[action,'Date']
    rating = current_ratings.loc[action,'Rating']
    
    # We need to adress the part of the dataframe where the company is the same and the date higher
    df_rated.loc[(df_rated['difflib']==company)&(df_rated['Report Date']>=date),'Rating'] = rating

# %%
# Checking the result
# df_rated[df_rated['difflib']==companies[0]]

# That worked correctly, we can apply it to our whole dataframe

# %%
def assign_ratings():
    # List of companies 
    companies = list(df_rated['difflib'].unique())
    for company in companies:
        # Creating the subframe
        current_ratings = ratings_df[ratings_df['Company_lower']==company].sort_values(by = ['Date'], ascending = True).reset_index(drop = True)
        for action in range(len(current_ratings)):
            # Getting the needed information
            company = current_ratings.loc[action,'Company_lower']
            date = current_ratings.loc[action,'Date']
            rating = current_ratings.loc[action,'Rating']
             # We need to adress the part of the dataframe where the company is the same and the date higher
            df_rated.loc[(df_rated['difflib']==company)&(df_rated['Report Date']>=date),'Rating'] = rating

# %%
# We apply the ratings
assign_ratings()

# %%
# Checking results
df_rated.isna().sum()
# Out:
# Ticker                                                0
# Company Name                                          0
# IndustryId                                            0
# Fiscal Year                                           0
# Fiscal Period                                         0
# Report Date                                          95
# Shares (Diluted)                                     95
# Cash, Cash Equivalents & Short Term Investments      95
# Accounts & Notes Receivable                          95
# Total Current Assets                                 95
# Property, Plant & Equipment, Net                     95
# Other Long Term Assets                               95
# Total Noncurrent Assets                              95
# Total Assets                                         95
# Payables & Accruals                                  95
# Total Current Liabilities                            95
# Total Noncurrent Liabilities                         95
# Total Liabilities                                    95
# Share Capital & Additional Paid-In Capital           95
# Retained Earnings                                    95
# Total Equity                                         95
# Revenue                                               2
# Cost of Revenue                                     204
# Gross Profit                                        204
# Operating Expenses                                    0
# Selling, General & Administrative                   330
# Operating Income (Loss)                               0
# Non-Operating Income (Loss)                           0
# Interest Expense, Net                               222
# Pretax Income (Loss), Adj.                            0
# Abnormal Gains (Losses)                               0
# Pretax Income (Loss)                                  0
# Income Tax (Expense) Benefit, Net                    54
# Income (Loss) from Continuing Operations              0
# Net Extraordinary Gains (Losses)                      0
# Net Income                                            0
# Net Income (Common)                                   0
# Sector                                                0
# Industry                                              0
# difflib                                               0
# Rating                                             1102
# dtype: int64

# %%
# We got almost everything rated
df_rated[df_rated['Rating'].isna()]
# Out:
#       Ticker                           Company Name  IndustryId  Fiscal Year  \
# 18252    KMG                      KMG CHEMICALS INC    110001.0         2017
# 7091    CLDR                         Cloudera, Inc.    101003.0         2016
# 21862   MRVL           MARVELL TECHNOLOGY GROUP LTD    101004.0         2016
# 33972   UNFI               UNITED NATURAL FOODS INC    102001.0         2017
# 20063      M                           Macy's, Inc.    103002.0         2016
# ...      ...                                    ...         ...          ...
# 37798   UNFI               UNITED NATURAL FOODS INC    102001.0         2022
# 37811   VRNT                     VERINT SYSTEMS INC    101003.0         2021
# 37812   VSCO                Victoria's Secret & Co.    103004.0         2021
# 37821    WMT                            Walmart Inc    102001.0         2021
# 37822   WOOF  Petco Health & Wellness Company, Inc.    103015.0         2021
#
#       Fiscal Period Report Date  Shares (Diluted)  \
# 18252            Q2  2017-01-31        12293000.0
# 7091             Q4  2017-01-31        36848463.0
# 21862            Q4  2017-01-31       520623000.0
# 33972            Q2  2017-01-31        50755000.0
# 20063            Q4  2017-01-31       307800000.0
# ...             ...         ...               ...
# 37798            Q2         NaN               NaN
# 37811            Q4         NaN               NaN
# 37812            Q4         NaN               NaN
# 37821            Q4         NaN               NaN
# 37822            Q4         NaN               NaN
#
#        Cash, Cash Equivalents & Short Term Investments  \
# 18252                                     3.058700e+07
# 7091                                      2.349560e+08
# 21862                                     1.668360e+09
# 33972                                     3.065800e+07
# 20063                                     1.297000e+09
# ...                                                ...
# 37798                                              NaN
# 37811                                              NaN
# 37812                                              NaN
# 37821                                              NaN
# 37822                                              NaN
#
#        Accounts & Notes Receivable  Total Current Assets  ...  \
# 18252                   35309000.0          1.124910e+08  ...
# 7091                   101549000.0          3.497020e+08  ...
# 21862                  335384000.0          2.290434e+09  ...
# 33972                  514870000.0          1.638398e+09  ...
# 20063                  522000000.0          7.626000e+09  ...
# ...                            ...                   ...  ...
# 37798                          NaN                   NaN  ...
# 37811                          NaN                   NaN  ...
# 37812                          NaN                   NaN  ...
# 37821                          NaN                   NaN  ...
# 37822                          NaN                   NaN  ...
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 18252          8.582000e+06                      -2.097000e+06
# 7091          -3.173900e+07                      -7.610000e+05
# 21862          4.819000e+06                      -6.834500e+07
# 33972          4.202800e+07                      -1.654600e+07
# 20063          7.280000e+08                      -2.560000e+08
# ...                     ...                                ...
# 37798          9.300000e+07                      -2.500000e+07
# 37811          6.115000e+06                      -1.037500e+07
# 37812          3.220000e+08                      -7.600000e+07
# 37821          4.782000e+09                      -1.149000e+09
# 37822          3.358400e+07                      -9.688000e+06
#
#        Income (Loss) from Continuing Operations  \
# 18252                              6.485000e+06
# 7091                              -3.250000e+07
# 21862                             -6.352600e+07
# 33972                              2.548200e+07
# 20063                              4.720000e+08
# ...                                         ...
# 37798                              6.800000e+07
# 37811                             -4.260000e+06
# 37812                              2.460000e+08
# 37821                              3.633000e+09
# 37822                              2.728800e+07
#
#        Net Extraordinary Gains (Losses)    Net Income  Net Income (Common)  \
# 18252                               0.0  6.485000e+06         6.485000e+06
# 7091                                0.0 -3.250000e+07        -3.250000e+07
# 21862                               0.0 -8.009100e+07        -8.009100e+07
# 33972                               0.0  2.548200e+07         2.548200e+07
# 20063                               0.0  4.750000e+08         4.750000e+08
# ...                                 ...           ...                  ...
# 37798                               0.0  6.600000e+07         6.600000e+07
# 37811                               0.0 -4.623000e+06        -9.823000e+06
# 37812                               0.0  2.460000e+08         2.460000e+08
# 37821                               0.0  3.562000e+09         3.562000e+09
# 37822                               0.0  2.899400e+07         2.899400e+07
#
#                    Sector                             Industry  \
# 18252     Basic Materials                            Chemicals
# 7091           Technology                 Application Software
# 21862          Technology                       Semiconductors
# 33972  Consumer Defensive                   Retail - Defensive
# 20063   Consumer Cyclical         Retail - Apparel & Specialty
# ...                   ...                                  ...
# 37798  Consumer Defensive                   Retail - Defensive
# 37811          Technology                 Application Software
# 37812   Consumer Cyclical  Manufacturing - Apparel & Furniture
# 37821  Consumer Defensive                   Retail - Defensive
# 37822   Consumer Cyclical                     Travel & Leisure
#
#                                        difflib  Rating
# 18252                      kmg chemicals, inc.     NaN
# 7091                             cloudera, inc     NaN
# 21862            marvell technology group ltd.     NaN
# 33972                united natural foods, inc     NaN
# 20063                             macy's, inc.     NaN
# ...                                        ...     ...
# 37798                united natural foods, inc     NaN
# 37811                      verint systems inc.     NaN
# 37812                  victoria's secret & co.     NaN
# 37821                             walmart inc.     NaN
# 37822  petco health and wellness company, inc.     NaN
#
# [1102 rows x 41 columns]

# %%
ratings_df[ratings_df['Company_lower']=="prog holdings, inc."]
# Out:
#                    Company        Date Rating        Company_lower
# 59715  PROG HOLDINGS, INC.  2021-11-08     B1  prog holdings, inc.

# %% [markdown]
# I looked through a few of them and realized, that the NaNs are created for the quarters where there is no rating available yet for the companies, so we drop those lines.

# %%
df_rated.shape
# Out:
# (7181, 41)

# %%
df_rated = df_rated.dropna(axis='rows')

# %%
df_rated.shape
# Out:
# (5415, 41)

# %%
# By doing this, all other NaNs vanished also
df_rated.isna().sum()
# Out:
# Ticker                                             0
# Company Name                                       0
# IndustryId                                         0
# Fiscal Year                                        0
# Fiscal Period                                      0
# Report Date                                        0
# Shares (Diluted)                                   0
# Cash, Cash Equivalents & Short Term Investments    0
# Accounts & Notes Receivable                        0
# Total Current Assets                               0
# Property, Plant & Equipment, Net                   0
# Other Long Term Assets                             0
# Total Noncurrent Assets                            0
# Total Assets                                       0
# Payables & Accruals                                0
# Total Current Liabilities                          0
# Total Noncurrent Liabilities                       0
# Total Liabilities                                  0
# Share Capital & Additional Paid-In Capital         0
# Retained Earnings                                  0
# Total Equity                                       0
# Revenue                                            0
# Cost of Revenue                                    0
# Gross Profit                                       0
# Operating Expenses                                 0
# Selling, General & Administrative                  0
# Operating Income (Loss)                            0
# Non-Operating Income (Loss)                        0
# Interest Expense, Net                              0
# Pretax Income (Loss), Adj.                         0
# Abnormal Gains (Losses)                            0
# Pretax Income (Loss)                               0
# Income Tax (Expense) Benefit, Net                  0
# Income (Loss) from Continuing Operations           0
# Net Extraordinary Gains (Losses)                   0
# Net Income                                         0
# Net Income (Common)                                0
# Sector                                             0
# Industry                                           0
# difflib                                            0
# Rating                                             0
# dtype: int64

# %% [markdown]
# ## Saving our finalized dataframe

# %%
df_rated.to_csv('Prepared Frames/rated.csv', index=False)
