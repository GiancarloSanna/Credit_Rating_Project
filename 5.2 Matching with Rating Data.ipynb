# %% [markdown]
# # We match our rating data to the main dataset

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from datetime import date

# %% [markdown]
# ## Loading data

# %%
ratings_df = pd.read_csv('Prepared Frames/rating_data.csv')
df_companies = pd.read_csv('Prepared Frames/companies_approx_match.csv')
main_df = pd.read_csv('Prepared Frames/main_data.csv')

# %% [markdown]
# ## Merging the found matches to the main Dataframe

# %%
main_df = pd.merge(left = main_df,
                                 right = df_companies[['Ticker','difflib']],
                                 # We use outer to not loose Information, we will have to get rid of some NaNs later
                                 how = 'left', 
                                 left_on = ['Ticker'], 
                                 right_on= ['Ticker'])

# %% [markdown]
# ## Assigning the ratings
# We now have to assign the ratings. The difficulty is, that we don't have the exact dates to match, but have to match when the date in the main dataframe is greater than the one for the rating and have to overwrite it with a new rating in case there is one.

# %%
# We can only assign ratings where we have found the companies, 
# we create a new dataframe just with these entries
df_rated = main_df[main_df['difflib'].isna()==False].copy()

# %%
# We sort the dataframe by dates
df_rated = df_rated.sort_values(by = ['Report Date'], ascending = True)
df_rated.head(3)
# Out:
#       Ticker                             Company Name  IndustryId  \
# 18103   KEYS              Keysight Technologies, Inc.    101001.0
# 14236    GME                           GameStop Corp.    103002.0
# 28690   SAIC  Science Applications International Corp    101003.0
#
#        Fiscal Year Fiscal Period Report Date  Shares (Diluted)  \
# 18103         2017            Q1  2017-01-31       173000000.0
# 14236         2016            Q4  2017-01-31       410400000.0
# 28690         2016            Q4  2017-01-31        47000000.0
#
#        Cash, Cash Equivalents & Short Term Investments  \
# 18103                                      896000000.0
# 14236                                      669400000.0
# 28690                                      210000000.0
#
#        Accounts & Notes Receivable  Total Current Assets  ...  \
# 18103                  395000000.0          1.932000e+09  ...
# 14236                  220900000.0          2.140700e+09  ...
# 28690                  427000000.0          7.890000e+08  ...
#
#        Change in Fixed Assets & Intangibles  \
# 18103                            -8000000.0
# 14236                           -36900000.0
# 28690                            -4000000.0
#
#        Net Cash from Acquisitions & Divestitures  \
# 18103                                -62800000.0
# 14236                                  -100000.0
# 28690                                        0.0
#
#        Net Cash from Investing Activities  Cash from (Repayment of) Debt  \
# 18103                          -8000000.0                   5.369231e+07
# 14236                         -35900000.0                  -2.000000e+05
# 28690                          -4000000.0                   0.000000e+00
#
#        Cash from (Repurchase of) Equity  Net Cash from Financing Activities  \
# 18103                        19000000.0                          21000000.0
# 14236                       -19800000.0                         -58100000.0
# 28690                       -41000000.0                         -53000000.0
#
#        Net Change in Cash             Sector                      Industry  \
# 18103           113000000         Technology             Computer Hardware
# 14236           311600000  Consumer Cyclical  Retail - Apparel & Specialty
# 28690             5000000         Technology          Application Software
#
#                                        difflib
# 18103              keysight technologies, inc.
# 14236                           gamestop corp.
# 28690  science applications international corp
#
# [3 rows x 36 columns]

# %%
# Since we matched the names of the companies on the lowercase version, we have to create a column  with that version again
ratings_df['Company_lower'] = ratings_df['Company'].apply(lambda x: x.lower())

# %%
# We create a list of all unique companies in our ratings dataframe
companies = list(df_rated['difflib'].unique())

# %% [markdown]
# #### Checking if we can match right

# %%
df_rated[df_rated['difflib']==companies[0]].head(2)
# Out:
#       Ticker                 Company Name  IndustryId  Fiscal Year  \
# 18103   KEYS  Keysight Technologies, Inc.    101001.0         2017
# 18104   KEYS  Keysight Technologies, Inc.    101001.0         2017
#
#       Fiscal Period Report Date  Shares (Diluted)  \
# 18103            Q1  2017-01-31       173000000.0
# 18104            Q2  2017-04-30       179000000.0
#
#        Cash, Cash Equivalents & Short Term Investments  \
# 18103                                     8.960000e+08
# 18104                                     1.023000e+09
#
#        Accounts & Notes Receivable  Total Current Assets  ...  \
# 18103                  395000000.0          1.932000e+09  ...
# 18104                  518000000.0          2.314000e+09  ...
#
#        Change in Fixed Assets & Intangibles  \
# 18103                            -8000000.0
# 18104                           -17000000.0
#
#        Net Cash from Acquisitions & Divestitures  \
# 18103                                -62800000.0
# 18104                                -62800000.0
#
#        Net Cash from Investing Activities  Cash from (Repayment of) Debt  \
# 18103                       -8.000000e+06                   5.369231e+07
# 18104                       -1.634000e+09                   1.239000e+09
#
#        Cash from (Repurchase of) Equity  Net Cash from Financing Activities  \
# 18103                        19000000.0                        2.100000e+07
# 18104                       446000000.0                        1.656000e+09
#
#        Net Change in Cash      Sector           Industry  \
# 18103           113000000  Technology  Computer Hardware
# 18104            87000000  Technology  Computer Hardware
#
#                            difflib
# 18103  keysight technologies, inc.
# 18104  keysight technologies, inc.
#
# [2 rows x 36 columns]

# %%
ratings_df[ratings_df['Company_lower']==companies[0]]
# Out:
#                            Company        Date Rating  \
# 67445  Keysight Technologies, Inc.  2014-09-12   Baa3
# 67446  Keysight Technologies, Inc.  2019-08-14   Baa2
#
#                      Company_lower
# 67445  keysight technologies, inc.
# 67446  keysight technologies, inc.

# %%
ratings_df.columns
# Out:
# Index(['Company', 'Date', 'Rating', 'Company_lower'], dtype='object')

# %% [markdown]
# #### We have to make sure to overwrite only the greater dates with updated rating information
# We will test it manually for the first company and do the rest with a function

# %%
# First create a sub-dataframe only with the ratings we are interested in
current_ratings = ratings_df[ratings_df['Company_lower']==companies[0]].sort_values(by = ['Date'], ascending = True).reset_index(drop = True)
current_ratings
# Out:
#                        Company        Date Rating                Company_lower
# 0  Keysight Technologies, Inc.  2014-09-12   Baa3  keysight technologies, inc.
# 1  Keysight Technologies, Inc.  2019-08-14   Baa2  keysight technologies, inc.

# %%
for action in range(len(current_ratings)):
    # Getting the needed information
    company = current_ratings.loc[action,'Company_lower']
    date = current_ratings.loc[action,'Date']
    rating = current_ratings.loc[action,'Rating']
    
    # We need to adress the part of the dataframe where the company is the same and the date higher
    df_rated.loc[(df_rated['difflib']==company)&(df_rated['Report Date']>=date),'Rating'] = rating

# %%
# Checking the result
# df_rated[df_rated['difflib']==companies[0]]

That worked correctly, we can apply it to our whole dataframe

# %%
def assign_ratings():
    # List of companies 
    companies = list(df_rated['difflib'].unique())
    for company in companies:
        # Creating the subframe
        current_ratings = ratings_df[ratings_df['Company_lower']==company].sort_values(by = ['Date'], ascending = True).reset_index(drop = True)
        for action in range(len(current_ratings)):
            # Getting the needed information
            company = current_ratings.loc[action,'Company_lower']
            date = current_ratings.loc[action,'Date']
            rating = current_ratings.loc[action,'Rating']
             # We need to adress the part of the dataframe where the company is the same and the date higher
            df_rated.loc[(df_rated['difflib']==company)&(df_rated['Report Date']>=date),'Rating'] = rating

# %%
# We apply the ratings
assign_ratings()

# %%
# Checking results
df_rated.isna().sum()
# Out:
# Ticker                                                0
# Company Name                                          0
# IndustryId                                            0
# Fiscal Year                                           0
# Fiscal Period                                         0
# Report Date                                           0
# Shares (Diluted)                                      0
# Cash, Cash Equivalents & Short Term Investments       0
# Accounts & Notes Receivable                           0
# Total Current Assets                                  0
# Property, Plant & Equipment, Net                      0
# Other Long Term Assets                                0
# Total Noncurrent Assets                               0
# Total Assets                                          0
# Payables & Accruals                                   0
# Total Current Liabilities                             0
# Total Noncurrent Liabilities                          0
# Total Liabilities                                     0
# Share Capital & Additional Paid-In Capital            0
# Retained Earnings                                     0
# Total Equity                                          0
# Net Income/Starting Line                              0
# Depreciation & Amortization                           0
# Non-Cash Items                                        0
# Change in Working Capital                             0
# Net Cash from Operating Activities                    0
# Change in Fixed Assets & Intangibles                  0
# Net Cash from Acquisitions & Divestitures             0
# Net Cash from Investing Activities                    0
# Cash from (Repayment of) Debt                         0
# Cash from (Repurchase of) Equity                      0
# Net Cash from Financing Activities                    0
# Net Change in Cash                                    0
# Sector                                                0
# Industry                                              0
# difflib                                               0
# Rating                                             1007
# dtype: int64

# %%
# We got almost everything rated
df_rated[df_rated['Rating'].isna()]
# Out:
#       Ticker              Company Name  IndustryId  Fiscal Year Fiscal Period  \
# 15683    HQY          HEALTHEQUITY INC    101003.0         2016            Q4
# 20063      M              Macy's, Inc.    103002.0         2016            Q4
# 33972   UNFI  UNITED NATURAL FOODS INC    102001.0         2017            Q2
# 7091    CLDR            Cloudera, Inc.    101003.0         2016            Q4
# 18252    KMG         KMG CHEMICALS INC    110001.0         2017            Q2
# ...      ...                       ...         ...          ...           ...
# 5441     BXC    BlueLinx Holdings Inc.    110005.0         2021            Q2
# 15701    HQY          HEALTHEQUITY INC    101003.0         2021            Q2
# 5442     BXC    BlueLinx Holdings Inc.    110005.0         2021            Q3
# 26520    PRO       PROS Holdings, Inc.    101003.0         2021            Q3
# 26418    PRG       PROG Holdings, Inc.    104007.0         2021            Q3
#
#       Report Date  Shares (Diluted)  \
# 15683  2017-01-31        60453000.0
# 20063  2017-01-31       307800000.0
# 33972  2017-01-31        50755000.0
# 7091   2017-01-31        36848463.0
# 18252  2017-01-31        12293000.0
# ...           ...               ...
# 5441   2021-06-30         9858000.0
# 15701  2021-07-31        83509000.0
# 5442   2021-09-30         9714000.0
# 26520  2021-09-30        44318000.0
# 26418  2021-09-30        66385000.0
#
#        Cash, Cash Equivalents & Short Term Investments  \
# 15683                                     1.803590e+08
# 20063                                     1.297000e+09
# 33972                                     3.065800e+07
# 7091                                      2.349560e+08
# 18252                                     3.058700e+07
# ...                                                ...
# 5441                                      1.790000e+05
# 15701                                     7.537540e+08
# 5442                                      1.860000e+05
# 26520                                     3.086420e+08
# 26418                                     1.287880e+08
#
#        Accounts & Notes Receivable  Total Current Assets  ...  \
# 15683                   17001000.0          2.008190e+08  ...
# 20063                  522000000.0          7.626000e+09  ...
# 33972                  514870000.0          1.638398e+09  ...
# 7091                   101549000.0          3.497020e+08  ...
# 18252                   35309000.0          1.124910e+08  ...
# ...                            ...                   ...  ...
# 5441                   437217000.0          8.993900e+08  ...
# 15701                   74223000.0          8.606140e+08  ...
# 5442                   344974000.0          8.204260e+08  ...
# 26520                   43125000.0          3.681300e+08  ...
# 26418                  180231000.0          8.977520e+08  ...
#
#        Net Cash from Acquisitions & Divestitures  \
# 15683                               0.000000e+00
# 20063                               0.000000e+00
# 33972                               9.200000e+04
# 7091                                0.000000e+00
# 18252                              -1.280460e+08
# ...                                          ...
# 5441                               -4.886443e+07
# 15701                              -2.344000e+06
# 5442                               -4.886443e+07
# 26520                              -2.482440e+07
# 26418                              -1.930000e+05
#
#        Net Cash from Investing Activities  Cash from (Repayment of) Debt  \
# 15683                          -3275000.0                            0.0
# 20063                         304000000.0                   -628000000.0
# 33972                         -15366000.0                    -71933000.0
# 7091                           75626000.0                            0.0
# 18252                          -2676000.0                      7700000.0
# ...                                   ...                            ...
# 5441                           -1488000.0                    -38103000.0
# 15701                         -20467000.0                            0.0
# 5442                           -1972000.0                    -97300000.0
# 26520                          -2516000.0                      -288000.0
# 26418                         -13848000.0                    -41233000.0
#
#        Cash from (Repurchase of) Equity  Net Cash from Financing Activities  \
# 15683                         2596000.0                           3321000.0
# 20063                       -81000000.0                        -957000000.0
# 33972                          165000.0                         -71791000.0
# 7091                         -1015000.0                          -1015000.0
# 18252                        43909250.0                           7124000.0
# ...                                 ...                                 ...
# 5441                                0.0                         -45721000.0
# 15701                         2483000.0                            200000.0
# 5442                                0.0                        -102279000.0
# 26520                         1515000.0                           1227000.0
# 26418                       -50760000.0                         -50962000.0
#
#        Net Change in Cash              Sector                      Industry  \
# 15683            14608000          Technology          Application Software
# 20063           840000000   Consumer Cyclical  Retail - Apparel & Specialty
# 33972            17102000  Consumer Defensive            Retail - Defensive
# 7091             42738000          Technology          Application Software
# 18252            12981000     Basic Materials                     Chemicals
# ...                   ...                 ...                           ...
# 5441                    0     Basic Materials            Building Materials
# 15701            16981000          Technology          Application Software
# 5442                 7000     Basic Materials            Building Materials
# 26520            -9684000          Technology          Application Software
# 26418            -8761000  Financial Services               Credit Services
#
#                          difflib  Rating
# 15683         healthequity, inc.     NaN
# 20063               macy's, inc.     NaN
# 33972  united natural foods, inc     NaN
# 7091               cloudera, inc     NaN
# 18252        kmg chemicals, inc.     NaN
# ...                          ...     ...
# 5441      bluelinx holdings inc.     NaN
# 15701         healthequity, inc.     NaN
# 5442      bluelinx holdings inc.     NaN
# 26520        prog holdings, inc.     NaN
# 26418        prog holdings, inc.     NaN
#
# [1007 rows x 37 columns]

# %%
ratings_df[ratings_df['Company_lower']=="prog holdings, inc."]
# Out:
#                    Company        Date Rating        Company_lower
# 80887  PROG HOLDINGS, INC.  2021-11-08     B1  prog holdings, inc.

# %% [markdown]
# I looked through a few of them and realized, that the NaNs are created for the quarters where there is no rating available yet for the companies, so we drop those lines.

# %%
df_rated.shape
# Out:
# (7086, 37)

# %%
df_rated = df_rated.dropna(axis='rows')

# %%
df_rated.shape
# Out:
# (6079, 37)

# %% [markdown]
# ## Saving our finalized dataframe

# %%
df_rated.to_csv('Prepared Frames/rated.csv', index=False)
