# %% [markdown]
# # We match our rating data to the main dataset

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from datetime import date

# %% [markdown]
# ## Loading data

# %%
ratings_df = pd.read_csv('Prepared Frames/rating_data.csv')
df_companies = pd.read_csv('Prepared Frames/companies_approx_match.csv')
main_df = pd.read_csv('Prepared Frames/main_data.csv')

# %% [markdown]
# ## Merging the found matches to the main Dataframe

# %%
main_df = pd.merge(left = main_df,
                                 right = df_companies[['Ticker','reduced_matches']],
                                 # We use outer to not loose Information, we will have to get rid of some NaNs later
                                 how = 'left', 
                                 left_on = ['Ticker'], 
                                 right_on= ['Ticker'])

# %% [markdown]
# ## Assigning the ratings
# We now have to assign the ratings. The difficulty is, that we don't have the exact dates to match, but have to match when the date in the main dataframe is greater than the one for the rating and have to overwrite it with a new rating in case there is one.

# %%
# We can only assign ratings where we have found the companies, 
# we create a new dataframe just with these entries
df_rated = main_df[main_df['reduced_matches'].isna()==False].copy()

# %%
# We sort the dataframe by dates
df_rated = df_rated.sort_values(by = ['Report Date'], ascending = True)
df_rated.head(3)
# Out:
#       Ticker                Company Name  IndustryId  Fiscal Year  \
# 18826     LE            LANDS' END, INC.    103002.0         2016
# 33972   UNFI    UNITED NATURAL FOODS INC    102001.0         2017
# 29355    SFS  Smart & Final Stores, Inc.    102001.0         2016
#
#       Fiscal Period Report Date  Shares (Diluted)  \
# 18826            Q4  2017-01-31        31750000.0
# 33972            Q2  2017-01-31        50755000.0
# 29355            Q4  2017-01-31        82302386.0
#
#        Cash, Cash Equivalents & Short Term Investments  \
# 18826                                      213108000.0
# 33972                                       30658000.0
# 29355                                       54235000.0
#
#        Accounts & Notes Receivable  Total Current Assets  ...  \
# 18826                   39284000.0          6.074000e+08  ...
# 33972                  514870000.0          1.638398e+09  ...
# 29355                   31809000.0          4.356360e+08  ...
#
#        Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 18826                      0.0          -157603000.0
# 33972                      0.0            42028000.0
# 29355                      0.0            -1903000.0
#
#        Income Tax (Expense) Benefit, Net  \
# 18826                         62782000.0
# 33972                        -16546000.0
# 29355                          1650000.0
#
#        Income (Loss) from Continuing Operations  \
# 18826                               -94821000.0
# 33972                                25482000.0
# 29355                                 -253000.0
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)  \
# 18826                               0.0 -94821000.0          -94821000.0
# 33972                               0.0  25482000.0           25482000.0
# 29355                               0.0   -253000.0            -253000.0
#
#                    Sector                      Industry  \
# 18826   Consumer Cyclical  Retail - Apparel & Specialty
# 33972  Consumer Defensive            Retail - Defensive
# 29355  Consumer Defensive            Retail - Defensive
#
#                reduced_matches
# 18826               lands end
# 33972    united natural foods
# 29355  smart  final stores llc
#
# [3 rows x 40 columns]

# %%
# We create a list of all unique companies in our ratings dataframe
companies = list(df_rated['reduced_matches'].unique())

# %%
len(companies)
# Out:
# 652

# %% [markdown]
# #### Checking if we can match right

# %%
df_rated[df_rated['reduced_matches']==companies[0]].head(2)
# Out:
#       Ticker      Company Name  IndustryId  Fiscal Year Fiscal Period  \
# 18826     LE  LANDS' END, INC.    103002.0         2016            Q4
# 18827     LE  LANDS' END, INC.    103002.0         2017            Q1
#
#       Report Date  Shares (Diluted)  \
# 18826  2017-01-31        31750000.0
# 18827  2017-04-30        32002000.0
#
#        Cash, Cash Equivalents & Short Term Investments  \
# 18826                                      213108000.0
# 18827                                      139810000.0
#
#        Accounts & Notes Receivable  Total Current Assets  ...  \
# 18826                   39284000.0           607400000.0  ...
# 18827                   32731000.0           523764000.0  ...
#
#        Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 18826                      0.0          -157603000.0
# 18827                      0.0           -12103000.0
#
#        Income Tax (Expense) Benefit, Net  \
# 18826                         62782000.0
# 18827                          4264000.0
#
#        Income (Loss) from Continuing Operations  \
# 18826                               -94821000.0
# 18827                                -7839000.0
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)  \
# 18826                               0.0 -94821000.0          -94821000.0
# 18827                               0.0  -7839000.0           -7839000.0
#
#                   Sector                      Industry  reduced_matches
# 18826  Consumer Cyclical  Retail - Apparel & Specialty       lands end
# 18827  Consumer Cyclical  Retail - Apparel & Specialty       lands end
#
# [2 rows x 40 columns]

# %%
ratings_df[ratings_df['reduced_name']==companies[0]]
# Out:
#                 Company        Date Rating     Company_lower reduced_name
# 48056  Lands' End, Inc.  2014-03-05     B1  lands' end, inc.   lands end
# 48057  Lands' End, Inc.  2016-09-16     B2  lands' end, inc.   lands end
# 48058  Lands' End, Inc.  2017-04-27     B3  lands' end, inc.   lands end
# 48059  Lands' End, Inc.  2014-03-05     B1  lands' end, inc.   lands end
# 48060  Lands' End, Inc.  2016-09-16     B2  lands' end, inc.   lands end
# 48061  Lands' End, Inc.  2017-04-27     B3  lands' end, inc.   lands end
# 48062  Lands' End, Inc.  2020-06-23   Caa1  lands' end, inc.   lands end
# 48063  Lands' End, Inc.  2020-10-16     B3  lands' end, inc.   lands end

# %%
ratings_df.columns
# Out:
# Index(['Company', 'Date', 'Rating', 'Company_lower', 'reduced_name'], dtype='object')

# %% [markdown]
# #### We have to make sure to overwrite only the greater dates with updated rating information
# We will test it manually for the first company and do the rest with a function

# %%
# First create a sub-dataframe only with the ratings we are interested in
current_ratings = ratings_df[ratings_df['reduced_name']==companies[0]].sort_values(by = ['Date'], ascending = True).reset_index(drop = True)
current_ratings
# Out:
#             Company        Date Rating     Company_lower reduced_name
# 0  Lands' End, Inc.  2014-03-05     B1  lands' end, inc.   lands end
# 1  Lands' End, Inc.  2014-03-05     B1  lands' end, inc.   lands end
# 2  Lands' End, Inc.  2016-09-16     B2  lands' end, inc.   lands end
# 3  Lands' End, Inc.  2016-09-16     B2  lands' end, inc.   lands end
# 4  Lands' End, Inc.  2017-04-27     B3  lands' end, inc.   lands end
# 5  Lands' End, Inc.  2017-04-27     B3  lands' end, inc.   lands end
# 6  Lands' End, Inc.  2020-06-23   Caa1  lands' end, inc.   lands end
# 7  Lands' End, Inc.  2020-10-16     B3  lands' end, inc.   lands end

# %%
for action in range(len(current_ratings)):
    # Getting the needed information
    company = current_ratings.loc[action,'reduced_name']
    date = current_ratings.loc[action,'Date']
    rating = current_ratings.loc[action,'Rating']
    
    # We need to adress the part of the dataframe where the company is the same and the date higher
    df_rated.loc[(df_rated['reduced_matches']==company)&(df_rated['Report Date']>=date),'Rating'] = rating

# %%
# Checking the result
# df_rated[df_rated['reduced_matches']==companies[0]]

# That worked correctly, we can apply it to our whole dataframe

# %%
def assign_ratings():
    # List of companies 
    companies = list(df_rated['reduced_matches'].unique())
    for company in companies:
        # Creating the subframe
        current_ratings = ratings_df[ratings_df['reduced_name']==company].sort_values(by = ['Date'], ascending = True).reset_index(drop = True)
        for action in range(len(current_ratings)):
            # Getting the needed information
            company = current_ratings.loc[action,'reduced_name']
            date = current_ratings.loc[action,'Date']
            rating = current_ratings.loc[action,'Rating']
             # We need to adress the part of the dataframe where the company is the same and the date higher
            df_rated.loc[(df_rated['reduced_matches']==company)&(df_rated['Report Date']>=date),'Rating'] = rating

# %%
# We apply the ratings
assign_ratings()

# %%
# Checking results
df_rated.isna().sum()
# Out:
# Ticker                                                0
# Company Name                                          0
# IndustryId                                            0
# Fiscal Year                                           0
# Fiscal Period                                         0
# Report Date                                         145
# Shares (Diluted)                                    145
# Cash, Cash Equivalents & Short Term Investments     145
# Accounts & Notes Receivable                         145
# Total Current Assets                                145
# Property, Plant & Equipment, Net                    145
# Other Long Term Assets                              145
# Total Noncurrent Assets                             145
# Total Assets                                        145
# Payables & Accruals                                 145
# Total Current Liabilities                           145
# Total Noncurrent Liabilities                        145
# Total Liabilities                                   145
# Share Capital & Additional Paid-In Capital          145
# Retained Earnings                                   145
# Total Equity                                        145
# Revenue                                               2
# Cost of Revenue                                     319
# Gross Profit                                        319
# Operating Expenses                                    0
# Selling, General & Administrative                   659
# Operating Income (Loss)                               0
# Non-Operating Income (Loss)                           0
# Interest Expense, Net                               237
# Pretax Income (Loss), Adj.                            0
# Abnormal Gains (Losses)                               0
# Pretax Income (Loss)                                  0
# Income Tax (Expense) Benefit, Net                    94
# Income (Loss) from Continuing Operations              0
# Net Extraordinary Gains (Losses)                      0
# Net Income                                            0
# Net Income (Common)                                   0
# Sector                                                0
# Industry                                              0
# reduced_matches                                       0
# Rating                                             1409
# dtype: int64

# %%
# We got almost everything rated
df_rated[df_rated['Rating'].isna()]
# Out:
#       Ticker                           Company Name  IndustryId  Fiscal Year  \
# 33972   UNFI               UNITED NATURAL FOODS INC    102001.0         2017
# 20063      M                           Macy's, Inc.    103002.0         2016
# 32343   TIVO                               TIVO INC    101003.0         2016
# 21862   MRVL           MARVELL TECHNOLOGY GROUP LTD    101004.0         2016
# 15683    HQY                       HEALTHEQUITY INC    101003.0         2016
# ...      ...                                    ...         ...          ...
# 37798   UNFI               UNITED NATURAL FOODS INC    102001.0         2022
# 37811   VRNT                     VERINT SYSTEMS INC    101003.0         2021
# 37812   VSCO                Victoria's Secret & Co.    103004.0         2021
# 37821    WMT                            Walmart Inc    102001.0         2021
# 37822   WOOF  Petco Health & Wellness Company, Inc.    103015.0         2021
#
#       Fiscal Period Report Date  Shares (Diluted)  \
# 33972            Q2  2017-01-31        50755000.0
# 20063            Q4  2017-01-31       307800000.0
# 32343            Q4  2017-01-31        67381277.0
# 21862            Q4  2017-01-31       520623000.0
# 15683            Q4  2017-01-31        60453000.0
# ...             ...         ...               ...
# 37798            Q2         NaN               NaN
# 37811            Q4         NaN               NaN
# 37812            Q4         NaN               NaN
# 37821            Q4         NaN               NaN
# 37822            Q4         NaN               NaN
#
#        Cash, Cash Equivalents & Short Term Investments  \
# 33972                                     3.065800e+07
# 20063                                     1.297000e+09
# 32343                                     6.460690e+08
# 21862                                     1.668360e+09
# 15683                                     1.803590e+08
# ...                                                ...
# 37798                                              NaN
# 37811                                              NaN
# 37812                                              NaN
# 37821                                              NaN
# 37822                                              NaN
#
#        Accounts & Notes Receivable  Total Current Assets  ...  \
# 33972                  514870000.0          1.638398e+09  ...
# 20063                  522000000.0          7.626000e+09  ...
# 32343                   55654000.0          7.358850e+08  ...
# 21862                  335384000.0          2.290434e+09  ...
# 15683                   17001000.0          2.008190e+08  ...
# ...                            ...                   ...  ...
# 37798                          NaN                   NaN  ...
# 37811                          NaN                   NaN  ...
# 37812                          NaN                   NaN  ...
# 37821                          NaN                   NaN  ...
# 37822                          NaN                   NaN  ...
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 33972          4.202800e+07                      -1.654600e+07
# 20063          7.280000e+08                      -2.560000e+08
# 32343         -3.277000e+06                       3.476000e+06
# 21862          4.819000e+06                      -6.834500e+07
# 15683          6.023000e+06                      -1.961000e+06
# ...                     ...                                ...
# 37798          9.300000e+07                      -2.500000e+07
# 37811          6.115000e+06                      -1.037500e+07
# 37812          3.220000e+08                      -7.600000e+07
# 37821          4.782000e+09                      -1.149000e+09
# 37822          3.358400e+07                      -9.688000e+06
#
#        Income (Loss) from Continuing Operations  \
# 33972                              2.548200e+07
# 20063                              4.720000e+08
# 32343                              1.990000e+05
# 21862                             -6.352600e+07
# 15683                              4.062000e+06
# ...                                         ...
# 37798                              6.800000e+07
# 37811                             -4.260000e+06
# 37812                              2.460000e+08
# 37821                              3.633000e+09
# 37822                              2.728800e+07
#
#        Net Extraordinary Gains (Losses)    Net Income  Net Income (Common)  \
# 33972                               0.0  2.548200e+07         2.548200e+07
# 20063                               0.0  4.750000e+08         4.750000e+08
# 32343                               0.0  1.990000e+05         1.990000e+05
# 21862                               0.0 -8.009100e+07        -8.009100e+07
# 15683                               0.0  4.062000e+06         4.062000e+06
# ...                                 ...           ...                  ...
# 37798                               0.0  6.600000e+07         6.600000e+07
# 37811                               0.0 -4.623000e+06        -9.823000e+06
# 37812                               0.0  2.460000e+08         2.460000e+08
# 37821                               0.0  3.562000e+09         3.562000e+09
# 37822                               0.0  2.899400e+07         2.899400e+07
#
#                    Sector                             Industry  \
# 33972  Consumer Defensive                   Retail - Defensive
# 20063   Consumer Cyclical         Retail - Apparel & Specialty
# 32343          Technology                 Application Software
# 21862          Technology                       Semiconductors
# 15683          Technology                 Application Software
# ...                   ...                                  ...
# 37798  Consumer Defensive                   Retail - Defensive
# 37811          Technology                 Application Software
# 37812   Consumer Cyclical  Manufacturing - Apparel & Furniture
# 37821  Consumer Defensive                   Retail - Defensive
# 37822   Consumer Cyclical                     Travel & Leisure
#
#                  reduced_matches  Rating
# 33972      united natural foods      NaN
# 20063                     macys      NaN
# 32343                      tivo      NaN
# 21862       marvell technology       NaN
# 15683              healthequity      NaN
# ...                          ...     ...
# 37798      united natural foods      NaN
# 37811            verint systems      NaN
# 37812         victorias secret       NaN
# 37821                   walmart      NaN
# 37822  pet health and wellness       NaN
#
# [1409 rows x 41 columns]

# %% [markdown]
# I looked through a few of them and realized, that the NaNs are created for the quarters where there is no rating available yet for the companies, so we drop those lines.

# %%
df_rated.shape
# Out:
# (11185, 41)

# %%
df_rated = df_rated.dropna(axis='rows')

# %%
df_rated.shape
# Out:
# (8662, 41)

# %%
# By doing this, all other NaNs vanished also
df_rated.isna().sum()
# Out:
# Ticker                                             0
# Company Name                                       0
# IndustryId                                         0
# Fiscal Year                                        0
# Fiscal Period                                      0
# Report Date                                        0
# Shares (Diluted)                                   0
# Cash, Cash Equivalents & Short Term Investments    0
# Accounts & Notes Receivable                        0
# Total Current Assets                               0
# Property, Plant & Equipment, Net                   0
# Other Long Term Assets                             0
# Total Noncurrent Assets                            0
# Total Assets                                       0
# Payables & Accruals                                0
# Total Current Liabilities                          0
# Total Noncurrent Liabilities                       0
# Total Liabilities                                  0
# Share Capital & Additional Paid-In Capital         0
# Retained Earnings                                  0
# Total Equity                                       0
# Revenue                                            0
# Cost of Revenue                                    0
# Gross Profit                                       0
# Operating Expenses                                 0
# Selling, General & Administrative                  0
# Operating Income (Loss)                            0
# Non-Operating Income (Loss)                        0
# Interest Expense, Net                              0
# Pretax Income (Loss), Adj.                         0
# Abnormal Gains (Losses)                            0
# Pretax Income (Loss)                               0
# Income Tax (Expense) Benefit, Net                  0
# Income (Loss) from Continuing Operations           0
# Net Extraordinary Gains (Losses)                   0
# Net Income                                         0
# Net Income (Common)                                0
# Sector                                             0
# Industry                                           0
# reduced_matches                                    0
# Rating                                             0
# dtype: int64

# %% [markdown]
# ## Saving our finalized dataframe

# %%
df_rated.to_csv('Prepared Frames/rated.csv', index=False)
